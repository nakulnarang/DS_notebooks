# %% [markdown]
# <a href="https://colab.research.google.com/github/nakulnarang/DS_notebooks/blob/main/Pokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from imgaug import augmenters as iaa

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np

# %%
img1 = image.load_img("1.jpg")
img2 = image.load_img("4.jpg")

img1 = image.img_to_array(img1)/255.0
img2 = image.img_to_array(img2)/255.0

plt.imshow(img1)
plt.show()
plt.imshow(img2)
plt.show()

# %%
seq = iaa.Sequential([
    iaa.Crop(px=(0, 16)), # crop images from each side by 0 to 16px (randomly chosen)
    iaa.Fliplr(0.5), # horizontally flip 50% of the images
    iaa.GaussianBlur(sigma=(0, 3.0)), # blur images with a sigma of 0 to 3.0
    iaa.LinearContrast((0.75, 1.5)),
    iaa.PiecewiseAffine(scale=(0.01, 0.05)),
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-25, 25),
        shear=(-8, 8)
    )
])

# %%
batch = img1.reshape(1,*img1.shape)
batch.shape
# Out:
# (1, 982, 814, 3)

# %%
for epoch in range(10):
  output = seq(images=batch)
  print(output.shape)
  plt.imshow(output[0])
  plt.show()
# Out:
# (1, 982, 814, 3)
# (1, 982, 814, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 982, 814, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 982, 814, 3)
# (1, 982, 814, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 982, 814, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 982, 814, 3)
# (1, 982, 814, 3)
# (1, 982, 814, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 982, 814, 3)
